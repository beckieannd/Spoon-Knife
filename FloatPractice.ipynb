# %% [markdown]
# <a href="https://colab.research.google.com/github/beckieannd/Spoon-Knife/blob/main/FloatPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
First = 18.5
Second = 30
sum_result = First + Second
print(f"Sum: {sum_result}")
# Out:
#   File "/tmp/ipykernel_7743/1829814892.py", line 3
#     sum:
#          ^
# SyntaxError: invalid syntax

# %%
First = input ("First")
Second = input ("Second")
sum_result = float(First) + float(Second)
print(sum_result)
print(sum_result)
# Out:
# First18.5
# Second30
# 48.5
# 48.5
